# %% [markdown]
# # MN GeoSpatial Commons

# %%
# import request library
import requests

# %%
# make a response object for the url

r = requests.get("https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dnr/biota_dnr_native_prairies/shp_biota_dnr_native_prairies.zip")

# %%
# check response
print(r.status_code)
# Out:
# <Response [200]>

# %%
r = requests.get('https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_metc/water_metro_grndwater_flow_model/shp_water_metro_grndwater_flow_model.zip')

# %%
def download_url(url, save_path, chunk_size=128):
    r = requests.get(url, stream=True)
    with open(save_path, 'wb') as fd:
        for chunk in r.iter_content(chunk_size=chunk_size):
            fd.write(chunk)

# %%
open('metro_water_file', 'wb').write(r.content)
# Out:
# 592705

# %%
# make a response object for the url  # this didn't load shp

#payload = {'dataset': 'env_impaired_water','class': 'SHP'}  # define search parameters
r = requests.get('http://gisdata.mn.gov/api/3/action/package_list', params = payload) # create URL with search params

print(r.url)   # show generated url
print(r) # show response from server
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1670         else:
# -> 1671             _raise_current_error()
#    1672
#
# ...

# %%
# save file locally - open("file_name.csv", "wb").write(r.content) 
open("impaired_water.shp", "wb").write(r.content)
# Out:
# 929

# %%
# make a url with 
# how do you know what the key:values are?

payload = {'key1': 'value1', 'key2': 'value2'}
>>> r = requests.get('https://httpbin.org/get', params=payload)

# %%
prairie = r.get("https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dnr/biota_dnr_native_prairies/shp_biota_dnr_native_prairies.zip")

# %%
open('prairie_file', 'wb').write(prairie.content)

# %%
# make a response object for the url  # this didn't load shp

#payload = {'dataset': 'env_impaired_water','class': 'SHP'}  # define search parameters
r = requests.get('http://gisdata.mn.gov/api/3/action/package_list', params = payload) # create URL with search params

print(r.url)   # show generated url
print(r) # show response from server

# %%
water = requests.get("https://gisdata.mn.gov/api/3/action/package_list?q=water", auth=('user', 'pass'), verify=False)
water.json()  # this gets the dictionary
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gisdata.mn.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'help': 'https://gisdata.mn.gov/api/3/action/help_show?name=package_list',
#  'success': True,
#  'result': ['agri-agbmp-loans',
#   'agri-agroecoregions',
#   'agri-app-food-for-thought-maps',
#   'agri-app-inspection-territories',
#   'agri-bah-field-staff',
#   'agri-cropland-data-layer-2006',
#   'agri-cropland-data-layer-2007',
#   'agri-cropland-data-layer-2008',
#   'agri-cropland-data-layer-2009',
#   'agri-cropland-data-layer-2010',
#   'agri-cropland-data-layer-2011',
#   'agri-cropland-data-layer-2012',
#   'agri-cropland-data-layer-2013',
#   'agri-cropland-data-layer-2014',
#   'agri-cropland-data-layer-2015',
# ...

# %%
for i in range(0,140):                    
    print(station_info + str(i))

# %%
water = requests.get("https://gisdata.mn.gov/api/3/action/package_list?q=water", auth=('user', 'pass'), verify=False)
water.json()  # this gets the dictionary

# %%
https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dnr/env_listed_infested_waters/shp_env_listed_infested_waters.zip

# %%
water = requests.get("https://gisdata.mn.gov/api/3/action/tag_list?q=water", auth=('user', 'pass'), verify=False)
water.json()  # this gets the dictionary  search for keyword tags
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gisdata.mn.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'help': 'https://gisdata.mn.gov/api/3/action/help_show?name=tag_list',
#  'success': True,
#  'result': ['1 water supply planning working groups',
#   '2 primary drinking water supply sources',
#   '5 2015 master water supply plan community profiles',
#   'altered watercourse',
#   'breakwater',
#   'clean water',
#   'clean water fund',
#   'coldwater',
#   'coolwater',
#   'deepwater habitats',
#   'drinking water',
#   'drinking water supply management area',
#   'eurasian watermilfoil',
#   'groudwatershed',
#   'groundwater',
#   'ground water',
#   'groundwater flow model',
#   'ground water levels',
# ...
